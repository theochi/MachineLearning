# %% [markdown]
# <a href="https://colab.research.google.com/github/theochi/MachineLearning/blob/main/HW1/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**My First Notebook**
#
# * This demonstrates how to create a simple notebook.
# * etc.
#
# ![image.png](data:image/png;base64,...)

# %%
x = 245

print(x)
# Out:
# 245
