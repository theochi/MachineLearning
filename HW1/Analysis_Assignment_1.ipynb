# %% [markdown]
# <a href="https://colab.research.google.com/github/theochi/MachineLearning/blob/main/HW1/Analysis_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?*
#
# You need to have a file in GitHub where you want to save a copy of your Google Colab too. Once you do that you go from file to save a copy in GitHub. You then select the correct repository and the correct file path. Once you’ve done that you should be able to see all your work in the Google Colab in whichever file you saved in GitHub.
#
# *Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?*
#
# Everything worked on the first try.
#
# *Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).*
#
# Went to my GitHub and clicked on my profile. From there I clicked create a new repository and put a name and toggled the necessary requirements for what we needed. After that I created files for the different homework assignments.
#
# *Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?*
#
# Python is a coding language that is essential in machine learning and knowing it will allow you to easier learn and work with machine learning algorithms.
